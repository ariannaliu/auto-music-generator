# %%
import mido
from mido import Message, MidiFile, MidiTrack

# %%
mid = MidiFile()       #给自己的文件定的.mid后缀
track = MidiTrack()    #定义声部，一个MidoTrack()就是一个声部

# %%
# def beat(time_beat):            #与mido的拍子互换
#     miao = 60/time_beat
#     time = miao*1000
#     return time

def beat(time):            #与mido的拍子互换  
    time /= 60 * 1000  
    time = 1/time  
    return time  

def yin(yin,pai,qian=0,unit = track, liang=64,qi=2): #yin是音，pai是指时间（节拍），
    if type(yin)== str:               #qian是是音前多少拍
        yin = num(yin)                #liang是音量

    unit.append(Message('program_change',channel=0,program=qi,time=0))
    unit.append(Message('note_on',note=yin,velocity=liang,time=qian,channel=0))
    unit.append(Message('note_off',note=yin,velocity=liang,time=int(beat(pai)),channel=0))

# %%
zhuGe3 = [8, 8, 5, 8, 9, 9, 9, 6, 6, 6, 3, 6, 6, 6, 6, 3,
          4, 8, 4, 7, 9, 3, 9, 2, 6, 5, 6, 3, 3, 3, 3, 6,
          5, 6, 1, 2, 9, 3, 9, 6, 6, 3, 3, 5, 5, 5, 5, 6,
          8, 8, 8, 8, 9, 9, 9, 9, 3, 6, 6, 6, 6, 6, 6, 6,
          8, 8, 5, 8, 9, 9, 9, 6, 6, 6, 3, 3, 6, 6, 6, 3,
          4, 8, 4, 7, 9, 3, 9, 2, 6, 5, 6, 3, 3, 3, 3, 6,
          5, 6, 1, 2, 9, 3, 9, 6, 6, 3, 3, 5, 5, 6, 6, 6,
          8, 8, 8, 8, 9, 9, 9, "la","la","la","la","la","la","la","la","la"]

# %%
def zhuGe_reflect(num):
    if num == "la":
        result = 57
    elif num == 1:
        result = 60
    elif num == 2:
        result = 62
    elif num == 3:
        result = 64
    elif num == 4:
        result = 65
    elif num == 5:
        result = 67
    elif num == 6:
        result = 69
    elif num == 7:
        result = 71
    elif num == 8:
        result = 72
    elif num == 9:
        result = 74
    elif num == 0:
        result = 20
    return result

# %%
i=0
for i in range(128):    #16个小节，每小节8拍，一共128
    yin(zhuGe_reflect(zhuGe3[i]),160, 0,track,80,2)

# %%
track1 = MidiTrack()
track2 = MidiTrack()
track3 = MidiTrack()
rhythm1 = [-4,-5,-6,-6,
           -4,-5,-6,-6,
           -4,-5,-6,-6,
           -4,-5,-6,-6,
           -4,-5,-6,-6,
           -4,-5,-6,-6,
           -4,-5,-6,-6,
           -4,-5,-6,-6]
rhythm2 = [-6,-7,-1,-1,
           -6,-7,-1,-1,
           -6,-7,-1,-1,
           -6,-7,-1,-1,
           -6,-7,-1,-1,
           -6,-7,-1,-1,
           -6,-7,-1,-1,
           -6,-7,-1,-1,]
rhythm3 = [-1,-2,-3,-3,
           -1,-2,-3,-3,
           -1,-2,-3,-3,
           -1,-2,-3,-3,
           -1,-2,-3,-3,
           -1,-2,-3,-3,
           -1,-2,-3,-3,
           -1,-2,-3,-3]
def reflect_banzou(num):
    if num == -4:
        result = 53
    elif num == -5:
        result = 55
    elif num == -6:
        result = 57
    elif num == -7:
        result = 59
    elif num == -1:
        result = 60
    elif num == -2:
        result = 62
    elif num == -3:
        result = 64
    return result

a=0
for a in range(32):
    yin(reflect_banzou(rhythm1[a]),40, 0,track1,80,2)

b=0
for b in range(32):
    yin(reflect_banzou(rhythm2[b]),40, 0,track2,80,2)

c=0
for c in range(32):
    yin(reflect_banzou(rhythm3[c]),40, 0,track3,80,2)

# %%
fuGe5 = [2, 3, 2, 3,
-2, 5, 3, 5,
5, 3, -2, 5, 3, 3, -2, -2,
3, 3, 2, 2,
3, 3, 3, 3,
1, -2, -2, -2, -2, -2, -2, -2,

2, 3, 2, 3,
-2, 5, 3, 5,
5, 3, -2, 5, 3, 3, -2, -2,

3, 3, 2, 2,
3, 3, 3, 3,
1, -2, -2, -2, -2, -2, -2, -2]

# %%
def fuGe_reflect(num):
    if num == "la":
        result = 57
    elif num == 1:
        result = 60
    elif num == 2:
        result = 62
    elif num == 3:
        result = 64
    elif num == 4:
        result = 65
    elif num == 5:
        result = 67
    elif num == 6:
        result = 69
    elif num == 7:
        result = 71
    elif num == 8:
        result = 72
    elif num == 9:
        result = 74
    elif num == 4.5:
        result = 66
    elif num == -2:
        result = 57
    elif num == -3:
        result = 55
    return result

# %%
i=0
for i in range(64):    #16个小节，每小节8拍，一共128
    yin(fuGe_reflect(fuGe5[i]),160, 0,track,80,2)

# %%
rhythm1 = [-4,-5,-6,-6,
           -4,-5,-6,-6,
           -4,-5,-6,-6,
           -4,-5,-6,-6,
           -4,-5,-6,-6,
           -4,-5,-6,-6,
           -4,-5,-6,-6,
           -4,-5,-6,-6]
rhythm2 = [-6,-7,-1,-1,
           -6,-7,-1,-1,
           -6,-7,-1,-1,
           -6,-7,-1,-1,
           -6,-7,-1,-1,
           -6,-7,-1,-1,
           -6,-7,-1,-1,
           -6,-7,-1,-1,]
rhythm3 = [-1,-2,-3,-3,
           -1,-2,-3,-3,
           -1,-2,-3,-3,
           -1,-2,-3,-3,
           -1,-2,-3,-3,
           -1,-2,-3,-3,
           -1,-2,-3,-3,
           -1,-2,-3,-3]
def reflect_banzou(num):
    if num == -4:
        result = 53
    elif num == -5:
        result = 55
    elif num == -6:
        result = 57
    elif num == -7:
        result = 59
    elif num == -1:
        result = 60
    elif num == -2:
        result = 62
    elif num == -3:
        result = 64
    return result

a=0
for a in range(16):
    yin(reflect_banzou(rhythm1[a]),40, 0,track1,80,2)

b=0
for b in range(16):
    yin(reflect_banzou(rhythm2[b]),40, 0,track2,80,2)

c=0
for c in range(16):
    yin(reflect_banzou(rhythm3[c]),40, 0,track3,80,2)

# %%
import math

def map_remain(num):
    if num == 1:
        result = 1
    elif num == 1.5:
        result = 2
    elif num == 2:
        result = 3
    elif num == 2.5:
        result = 4
    elif num == 3:
        result = 5
    elif num == 4:
        result = 6
    elif num == 4.5:
        result = 7
    elif num == 5:
        result = 8
    elif num == 5.5:
        result = 9
    elif num == 6:
        result = 10
    elif num == 6.5:
        result = 11
    elif num == 0:
        result = 0
    return result        
        
        
def toMidi(vector):
    
    num = len(vector)
    trans_vector = []
    for i in range(num):
        base = 59   #基数是59
        target = vector[i]
        int_part = math.floor(target)     #得到target的整数部分
        times = math.floor(int_part/7)    #整数部分是由多少个7组成的
        base += times*12
        
        remain = target - times*7        #得到剩余部分
        base += map_remain(remain)
        trans_vector.append(base)
    return trans_vector

# %%
solo2 = [6, 6.0, 10.0, 6.0, 7, 11.5, 5.0, 9.0, 10, 8.0, 10.0, 10.0, 10, 5.0, 5.0, 6, 7, 8, 9, 10,
       8, 10.0, 6.0, 5.0, 9, 5.0, 7.0, 7.0, 6, 7.0, 11.5, 10.0, 6, 7, 8, 9, 10, 10, 10, 10,
       8, 8.0, 4.0, 5.0, 9, 5.0, 5.0, 5.0, 10, 10.0, 8.0, 10.0, 6, 4.0, 4.0, 10, 9, 8, 7, 6,
       8, 4.0, 11.0, 8.0, 7, 5.0, 5.0, 6.0, 8, 12.5, 12.5, 6.0, 6, 7, 8, 9, 10, 10, 10, 10,
       4, 4.0, 10.0, 11.0, 9, 6.0, 11.5, 9.0, 8, 10.0, 8.0, 10.0, 6, 5.0, 5.0, 6, 7, 8, 9, 10,
       8, 4.0, 6.0, 6.0, 5, 12.0, 5.0, 5.0, 8, 7.0, 10.0, 8.0, 6, 6.0, 5.0, 10, 9, 8, 7, 6,
       6, 8.0, 6.0, 6.0, 7, 7.0, 7.0, 12.0, 10, 8.0, 8.0, 11.5, 8, 8.0, 4.0, 10, 9, 8, 7, 6,
       6, 6.5, 8.0, 9.0, 9, 5.0, 8.0, 7.0, 8, 9.0, 7.0, 10.0, 6, 7, 8, 9, 10, 10, 10, 10]

# %%
import mido
from mido import Message, MidiFile, MidiTrack
import numpy as np
import random

# %%
#插入随机加音序列  FG之间各挑选一个，从0123中挑选，2*8=16个随机数
add_position_list = np.random.choice([0,1,2,3],16,p=[1/4,1/4,1/4, 1/4])

#add_yin_list也是16个音符，它与pos是一一对应关系
add_yin_list = []
i = 0
for i in range(16):
    if i%2 == 0:   #在F和弦下面
        fortune = np.random.choice(toMidi([4,5,6,6.5,8,9,10,11]),1,p=[1/5,2/25,1/5,2/25,1/5,2/25,2/25,2/25])
        add_yin_list.append(fortune[0])
    else:
        fortune = np.random.choice(toMidi([5,6,7,8,9,10,11.5,12]),1,p=[1/5,2/25,1/5,2/25,1/5,2/25,2/25,2/25])
        add_yin_list.append(fortune[0])

# %%
midi_vector = toMidi(solo2)
i=0
count = 0
for i in range(80):    #16个小节，每小节8拍，一共128
    target_yin = midi_vector[i]
    if (target_yin == 70)|(target_yin == 78)|(target_yin == 80):
#         target_yin +=1
        target_yin -=1
    if i % 20 <=3:
        add_pos = add_position_list[count]
        add_yin = add_yin_list[count]
        if add_pos == (i%20):
            
            if (add_yin == 70)|(add_yin == 78)|(add_yin == 80):
#                 add_yin +=1
                add_yin -=1
                yin(add_yin,320, 0,track,80,2)

            else:
                yin(add_yin,320, 0,track,80,2)
            yin(target_yin,320, 0,track,80,2)
        else:
            yin(target_yin,160, 0,track,80,2)
    elif (i%20<=7) & (i%20>3):
        add_pos = add_position_list[count+1]+4
        add_yin = add_yin_list[count+1]
        if add_pos == (i%20):
            if (add_yin == 70)|(add_yin == 78)|(add_yin == 80):
#                 add_yin +=1
                add_yin -=1
                yin(add_yin,320, 0,track,80,2)
            else:
                yin(add_yin,320, 0,track,80,2)
            
            yin(target_yin,320, 0,track,80,2)
        else:
            yin(target_yin,160, 0,track,80,2)
    elif (i%20<=11) & (i%20>7):
        yin(target_yin,160, 0,track,80,2)
        
    else:
        yin(target_yin,320, 0,track,80,2)
        if (i%20) == 19:
            count += 2

# %%
rhythm1 = [-4,-5,-6,-6,
           -4,-5,-6,-6,
           -4,-5,-6,-6,
           -4,-5,-6,-6,
           -4,-5,-6,-6,
           -4,-5,-6,-6,
           -4,-5,-6,-6,
           -4,-5,-6,-6]
rhythm2 = [-6,-7,-1,-1,
           -6,-7,-1,-1,
           -6,-7,-1,-1,
           -6,-7,-1,-1,
           -6,-7,-1,-1,
           -6,-7,-1,-1,
           -6,-7,-1,-1,
           -6,-7,-1,-1,]
rhythm3 = [-1,-2,-3,-3,
           -1,-2,-3,-3,
           -1,-2,-3,-3,
           -1,-2,-3,-3,
           -1,-2,-3,-3,
           -1,-2,-3,-3,
           -1,-2,-3,-3,
           -1,-2,-3,-3]
def reflect_banzou(num):
    if num == -4:
        result = 53
    elif num == -5:
        result = 55
    elif num == -6:
        result = 57
    elif num == -7:
        result = 59
    elif num == -1:
        result = 60
    elif num == -2:
        result = 62
    elif num == -3:
        result = 64
    return result

a=0
for a in range(16):
    yin(reflect_banzou(rhythm1[a]),40, 0,track1,80,2)

b=0
for b in range(16):
    yin(reflect_banzou(rhythm2[b]),40, 0,track2,80,2)

c=0
for c in range(16):
    yin(reflect_banzou(rhythm3[c]),40, 0,track3,80,2)

# %%
i=0
for i in range(128):    #16个小节，每小节8拍，一共128
    yin(zhuGe_reflect(zhuGe3[i]),160, 0,track,80,2)

# %%
rhythm1 = [-4,-5,-6,-6,
           -4,-5,-6,-6,
           -4,-5,-6,-6,
           -4,-5,-6,-6,
           -4,-5,-6,-6,
           -4,-5,-6,-6,
           -4,-5,-6,-6,
           -4,-5,-6,-6]
rhythm2 = [-6,-7,-1,-1,
           -6,-7,-1,-1,
           -6,-7,-1,-1,
           -6,-7,-1,-1,
           -6,-7,-1,-1,
           -6,-7,-1,-1,
           -6,-7,-1,-1,
           -6,-7,-1,-1,]
rhythm3 = [-1,-2,-3,-3,
           -1,-2,-3,-3,
           -1,-2,-3,-3,
           -1,-2,-3,-3,
           -1,-2,-3,-3,
           -1,-2,-3,-3,
           -1,-2,-3,-3,
           -1,-2,-3,-3]
def reflect_banzou(num):
    if num == -4:
        result = 53
    elif num == -5:
        result = 55
    elif num == -6:
        result = 57
    elif num == -7:
        result = 59
    elif num == -1:
        result = 60
    elif num == -2:
        result = 62
    elif num == -3:
        result = 64
    return result

a=0
for a in range(32):
    yin(reflect_banzou(rhythm1[a]),40, 0,track1,80,2)

b=0
for b in range(32):
    yin(reflect_banzou(rhythm2[b]),40, 0,track2,80,2)

c=0
for c in range(32):
    yin(reflect_banzou(rhythm3[c]),40, 0,track3,80,2)

# %%
i=0
for i in range(64):    #16个小节，每小节8拍，一共128
    yin(fuGe_reflect(fuGe5[i]),160, 0,track,80,2)

# %%
rhythm1 = [-4,-5,-6,-6,
           -4,-5,-6,-6,
           -4,-5,-6,-6,
           -4,-5,-6,-6,
           -4,-5,-6,-6,
           -4,-5,-6,-6,
           -4,-5,-6,-6,
           -4,-5,-6,-6]
rhythm2 = [-6,-7,-1,-1,
           -6,-7,-1,-1,
           -6,-7,-1,-1,
           -6,-7,-1,-1,
           -6,-7,-1,-1,
           -6,-7,-1,-1,
           -6,-7,-1,-1,
           -6,-7,-1,-1,]
rhythm3 = [-1,-2,-3,-3,
           -1,-2,-3,-3,
           -1,-2,-3,-3,
           -1,-2,-3,-3,
           -1,-2,-3,-3,
           -1,-2,-3,-3,
           -1,-2,-3,-3,
           -1,-2,-3,-3]
def reflect_banzou(num):
    if num == -4:
        result = 53
    elif num == -5:
        result = 55
    elif num == -6:
        result = 57
    elif num == -7:
        result = 59
    elif num == -1:
        result = 60
    elif num == -2:
        result = 62
    elif num == -3:
        result = 64
    return result

a=0
for a in range(16):
    yin(reflect_banzou(rhythm1[a]),40, 0,track1,80,2)

b=0
for b in range(16):
    yin(reflect_banzou(rhythm2[b]),40, 0,track2,80,2)

c=0
for c in range(16):
    yin(reflect_banzou(rhythm3[c]),40, 0,track3,80,2)

# %%
#插入随机加音序列  FG之间各挑选一个，从0123中挑选，2*8=16个随机数
add_position_list = np.random.choice([0,1,2,3],16,p=[1/4,1/4,1/4, 1/4])

#add_yin_list也是16个音符，它与pos是一一对应关系
add_yin_list = []
i = 0
for i in range(16):
    if i%2 == 0:   #在F和弦下面
        fortune = np.random.choice(toMidi([4,5,6,6.5,8,9,10,11]),1,p=[1/5,2/25,1/5,2/25,1/5,2/25,2/25,2/25])
        add_yin_list.append(fortune[0])
    else:
        fortune = np.random.choice(toMidi([5,6,7,8,9,10,11.5,12]),1,p=[1/5,2/25,1/5,2/25,1/5,2/25,2/25,2/25])
        add_yin_list.append(fortune[0])

# %%
track4 = MidiTrack()
midi_vector = toMidi(solo2)
i=0
count = 0
for i in range(80):    #16个小节，每小节8拍，一共128
    target_yin = midi_vector[i]
    if (target_yin == 70)|(target_yin == 78)|(target_yin == 80):
#         target_yin +=1
        target_yin -=1
    if i % 20 <=3:
        add_pos = add_position_list[count]
        add_yin = add_yin_list[count]
        if add_pos == (i%20):
            
            if (add_yin == 70)|(add_yin == 78)|(add_yin == 80):
#                 add_yin +=1
                add_yin -=1
                yin(add_yin,320, 0,track4,80,2)

            else:
                yin(add_yin,320, 0,track4,80,2)
            yin(target_yin,320, 0,track4,80,2)
        else:
            yin(target_yin,160, 0,track4,80,2)
    elif (i%20<=7) & (i%20>3):
        add_pos = add_position_list[count+1]+4
        add_yin = add_yin_list[count+1]
        if add_pos == (i%20):
            if (add_yin == 70)|(add_yin == 78)|(add_yin == 80):
#                 add_yin +=1
                add_yin -=1
                yin(add_yin,320, 0,track4,80,2)
            else:
                yin(add_yin,320, 0,track4,80,2)
            
            yin(target_yin,320, 0,track4,80,2)
        else:
            yin(target_yin,160, 0,track4,80,2)
    elif (i%20<=11) & (i%20>7):
        yin(target_yin,160, 0,track4,80,2)
        
    else:
        yin(target_yin,320, 0,track4,80,2)
        if (i%20) == 19:
            count += 2

# %%
mid.tracks.append(track)
mid.tracks.append(track1)
mid.tracks.append(track2)
mid.tracks.append(track3)
mid.tracks.append(track4)

mid.save('C:\\Users\\Administrator\\Desktop\\2020Summer\\大杂烩2.mid')
